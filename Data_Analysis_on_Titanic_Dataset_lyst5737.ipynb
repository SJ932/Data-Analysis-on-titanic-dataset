# %%
import pandas as pd
titanic=pd.read_csv('tested.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
# find the top 5 rows of your data
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.info()
titanic.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#drop duplicates

titanic.drop_duplicates(inplace=True)
titanic.reset_index(inplace=True, drop=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
#Checking for Null values
null_counts = titanic.isnull().sum()
if null_counts.sum() > 0:
    print("Missing values per column:")
    print(null_counts[null_counts > 0])
# Out:
# Missing values per column:
# Age       86
# Fare       1
# Cabin    327
# dtype: int64

# %%
687/891
# Out:
# 0.7710437710437711

# %% [markdown]
# ## Data Cleaning & Missing Value Handling

# %%
# If the number of entries is N, you have less than 5-10% missing values-- we can eliminate those rows

titanic= titanic[titanic.Embarked.notna()]

# If the number of entries is N, you have 30-50% missing values-- we can replace the rows with mean, median, mode
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)


#If the number of entries is N, you have above 70% missing values-- Use some intuition and eliminate the column

titanic= titanic.drop('Cabin', axis=1)

titanic.drop_duplicates(inplace=True)
titanic.reset_index(inplace=True, drop=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male  27.0      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male  27.0      0      0
# 417                      Peter, Master. Michael J    male  27.0      1      1
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# 2                240276    9.6875        Q
# 3                315154    8.6625        S
# 4               3101298   12.2875        S
# ..                  ...       ...      ...
# 413           A.5. 3236    8.0500        S
# 414            PC 17758  108.9000        C
# 415  SOTON/O.Q. 3101262    7.2500        S
# 416              359309    8.0500        S
# 417                2668   22.3583        C
#
# [418 rows x 11 columns]

# %%
#check columns
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
# check datatypes
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
import seaborn as sns
sns.boxplot(titanic['Parch'])
# Out:
# <Axes: ylabel='Parch'>

# %%
titanic= titanic[titanic.Fare<500]
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male  27.0      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male  27.0      0      0
# 417                      Peter, Master. Michael J    male  27.0      1      1
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# 2                240276    9.6875        Q
# 3                315154    8.6625        S
# 4               3101298   12.2875        S
# ..                  ...       ...      ...
# 413           A.5. 3236    8.0500        S
# 414            PC 17758  108.9000        C
# 415  SOTON/O.Q. 3101262    7.2500        S
# 416              359309    8.0500        S
# 417                2668   22.3583        C
#
# [416 rows x 11 columns]

# %%
import numpy as np
z_scores = np.abs((titanic[['Age', 'SibSp']] - titanic[['Age', 'SibSp']].mean()) / titanic[['Age', 'SibSp']].std())

# Detect outliers using a z-score threshold of 3
outlier_threshold = 3
outliers = titanic[(z_scores['Age'] > outlier_threshold) | (z_scores['SibSp'] > outlier_threshold)]

print("Outliers:")
print(outliers)
# Out:
# Outliers:
#      PassengerId  Survived  Pclass  \
# 55           947         0       3
# 96           988         1       1
# 140         1032         1       3
# 154         1046         0       3
# 188         1080         1       3
# 214         1106         1       3
# 360         1252         0       3
# 379         1271         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 55                                Rice, Master. Albert    male  10.0      4
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 140                        Goodwin, Miss. Jessie Allis  female  10.0      5
# 154                       Asplund, Master. Filip Oscar    male  13.0      4
# 188                                    Sage, Miss. Ada  female  27.0      8
# 214             Andersson, Miss. Ida Augusta Margareta  female  38.0      4
# 360                        Sage, Master. William Henry    male  14.5      8
# 379                        Asplund, Master. Carl Edgar    male   5.0      4
#
#      Parch    Ticket     Fare Embarked
# 55       1    382652  29.1250        Q
# 96       0     19877  78.8500        S
# 140      2   CA 2144  46.9000        S
# 154      2    347077  31.3875        S
# 188      2  CA. 2343  69.5500        S
# 214      2    347091   7.7750        S
# 360      2  CA. 2343  69.5500        S
# 379      2    347077  31.3875        S

# %%
# Winsorize the outliers by replacing them with the 95th percentile value
age_threshold = titanic['Age'].quantile(0.95)
SibSp_threshold = titanic['SibSp'].quantile(0.95)
titanic['Age'] = np.where(titanic['Age'] > age_threshold, age_threshold, titanic['Age'])
titanic['SibSp'] = np.where(titanic['SibSp'] > SibSp_threshold, SibSp_threshold, titanic['SibSp'])
# Out:
# C:\Users\SUJAL GUPTA\AppData\Local\Temp\ipykernel_14776\2013551631.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['Age'] = np.where(titanic['Age'] > age_threshold, age_threshold, titanic['Age'])
# C:\Users\SUJAL GUPTA\AppData\Local\Temp\ipykernel_14776\2013551631.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['SibSp'] = np.where(titanic['SibSp'] > SibSp_threshold, SibSp_threshold, titanic['SibSp'])

# %%
# drop columns
titanic.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)
# Out:
# C:\Users\SUJAL GUPTA\AppData\Local\Temp\ipykernel_14776\3008689439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)

# %%
#group by

survived = titanic.groupby('Survived').sum()
survived
# Out:
#           Pclass                                                Sex      Age  \
# Survived
# 0            618  malemalemalemalemalemalemalemalemalemalemalema...  7738.41
# 1            325  femalefemalefemalefemalefemalefemalefemalefema...  4395.59
#
#           SibSp  Parch       Fare  \
# Survived
# 0          86.0     73  7294.8874
# 1          74.0     90  7049.3210
#
#                                                    Embarked
# Survived
# 0         QQSSSSSSSQCCSCSCSCSSCCSSCSSSCQSCCQSSSSSSCSCSCC...
# 1         SSQCSSCSCSCCSSSSSSCSSSCQSQSQSCSQQSQSSSSCCQCQSS...

# %%
#filtering

female_passengers = titanic[titanic['Sex'] == 'female']
female_passengers
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 1           1       3  female  47.0    1.0      0    7.0000        S
# 4           1       3  female  22.0    1.0      1   12.2875        S
# 6           1       3  female  30.0    0.0      0    7.6292        Q
# 8           1       3  female  18.0    0.0      0    7.2292        C
# 12          1       1  female  23.0    1.0      0   82.2667        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 409         1       3  female   3.0    1.0      1   13.7750        S
# 410         1       3  female  27.0    0.0      0    7.7500        Q
# 411         1       1  female  37.0    1.0      0   90.0000        Q
# 412         1       3  female  28.0    0.0      0    7.7750        S
# 414         1       1  female  39.0    0.0      0  108.9000        C
#
# [151 rows x 8 columns]

# %%
# Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.histplot(data=titanic, x='Age', hue='Survived', bins=30, kde=True)
plt.title('Distribution of Passengers by Age and Survival')
plt.show()

plt.figure(figsize=(8, 6))
sns.countplot(data=titanic, x='Pclass', hue='Survived')
plt.title('Count of Passengers by Cabin Class and Survival')
plt.show()
